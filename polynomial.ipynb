# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# %%
df=pd.read_csv('polynomial.csv')

# %%
df
# Out:
#    Years of Experience Salary (in dollars)
# 0                    1              50,000
# 1                    2              55,000
# 2                    3              65,000
# 3                    4              80,000
# 4                    5             110,000
# 5                    6             150,000
# 6                    7             200,000

# %%
df['Salary (in dollars)'] = df['Salary (in dollars)'].str.replace(',','').astype(int)
df
# Out:
#    Years of Experience  Salary (in dollars)
# 0                    1                50000
# 1                    2                55000
# 2                    3                65000
# 3                    4                80000
# 4                    5               110000
# 5                    6               150000
# 6                    7               200000

# %%
X = df.iloc[:, 0:1].values
y = df.iloc[:, 1].values

# %%
X
# Out:
# array([[1],
#        [2],
#        [3],
#        [4],
#        [5],
#        [6],
#        [7]])

# %%
y
# Out:
# array([ 50000,  55000,  65000,  80000, 110000, 150000, 200000])

# %%
lin = LinearRegression()
lin.fit(X, y)
# Out:
# LinearRegression()

# %%
lin.predict([[8]])
# Out:
# array([199285.71428571])

# %%
poly = PolynomialFeatures(degree=4)
X_poly = poly.fit_transform(X)

poly.fit(X_poly, y)
lin2 = LinearRegression()
lin2.fit(X_poly, y)
# Out:
# LinearRegression()

# %%
plt.scatter(X, y, color='blue')

plt.plot(X, lin.predict(X), color='red')
plt.title('Linear Regression')
plt.xlabel('Years of Experience	')
plt.ylabel('Salary (in dollars)')

plt.show()
# Out:
# C:\Users\SG\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.scatter(X, y, color='blue')

plt.plot(X, lin2.predict(poly.fit_transform(X)),
         color='red')
plt.title('Polynomial Regression')
plt.xlabel('Years of Experience')
plt.ylabel('Salary (in dollars)')

plt.show()

# %%
predarray = np.array([[7]])
lin.predict(predarray)
# Out:
# array([174821.42857143])

# %%
pred2array = np.array([[10]])
lin2.predict(poly.fit_transform(pred2array))
# Out:
# array([341547.61904766])

# %%
lin2.score(X_poly,y)
# Out:
# 0.9998671426425906

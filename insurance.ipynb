# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Linear Regression with Sigmoid Y = 1/1e**(m*x+b)

# %%
df=pd.read_csv("insurance.csv")

# %%
df
# Out:
#     age  bought_insurance
# 0    22                 0
# 1    25                 0
# 2    47                 1
# 3    52                 0
# 4    46                 1
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 10   18                 0
# 11   28                 0
# 12   27                 0
# 13   29                 0
# 14   49                 1
# 15   55                 1
# 16   25                 1
# 17   58                 1
# 18   19                 0
# 19   18                 0
# 20   21                 0
# 21   26                 0
# 22   40                 1
# 23   45                 1
# 24   50                 1
# 25   54                 1
# 26   23                 0

# %%
plt.scatter(df.age,df.bought_insurance,marker = "+",color ="blue")

# %% [markdown]
# Y = 1/1e**(m*x+b) e=(2.71828)

# %%
type(df[['age']])
# Out:
# pandas.core.frame.DataFrame

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(df[['age']],df.bought_insurance,test_size=0.1)

# %%
x_train
# Out:
#     age
# 16   25
# 21   26
# 0    22
# 24   50
# 17   58
# 10   18
# 18   19
# 14   49
# 3    52
# 19   18
# 7    60
# 2    47
# 22   40
# 25   54
# 26   23
# 15   55
# 6    55
# 13   29
# 4    46
# 11   28
# 20   21
# 23   45
# 8    62
# 9    61

# %%
x_test
# Out:
#     age
# 1    25
# 12   27
# 5    56

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
model.predict(x_test)
# Out:
# array([0, 0, 1])

# %%
model.predict([[25]])
# Out:
# C:\Users\SG\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])

# %%
model.score(x_test,y_test)
# Out:
# 1.0

# %%
model.predict_proba(x_test)
# Out:
# array([[0.83691038, 0.16308962],
#        [0.800095  , 0.199905  ],
#        [0.09825359, 0.90174641]])
